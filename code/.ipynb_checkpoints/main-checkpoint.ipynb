# %% [markdown]
# # Dependency

# %%
import numpy as np
import math

from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold


import gc

import loading_function as load_data
import MCNN
# Out:
# 2023-10-05 11:05:35.192471: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-05 11:05:35.217427: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 11:05:35.532795: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # PARAM

# %%
NUM_DEPENDENT =5
MAXSEQ = NUM_DEPENDENT*2+1

DATA_TYPE = "ProtTrans"
#"/BinaryMatrix" "/MMseqs2" "/ProtTrans"


NUM_FILTER = 256
NUM_HIDDEN = 1000#100
BATCH_SIZE  = 1024
WINDOW_SIZES = [2,4,6,8,10]




NUM_CLASSES = 2

NUM_FEATURE = 1024
EPOCHS      = 30
K_Fold = 5
VALIDATION_MODE="cross"
#"independent" "cross"

# %% [markdown]
# # Main

# %%
# Example usage:
x_train, y_train,x_test, y_test = load_data.MCNN_data_load(DATA_TYPE,NUM_CLASSES,NUM_DEPENDENT)
# Out:
# Loading data: 100%|█████████████████████████| 646/646 [01:19<00:00,  8.08file/s]
# Loading data: 100%|███████████████████████████| 46/46 [00:05<00:00,  8.82file/s]

# %%
def model_test(model, x_test, y_test):
    
    print(x_test.shape)
    pred_test = model.predict(x_test)
    fpr, tpr, thresholds = roc_curve(y_test[:,1], pred_test[:, 1])
    AUC = metrics.auc(fpr, tpr)

    gmeans = np.sqrt(tpr * (1-fpr))
    ix = np.argmax(gmeans)
    #print(f'Best Threshold={thresholds[ix]}, G-Mean={gmeans[ix]}')
    threshold = thresholds[ix]
    y_pred = (pred_test[:, 1] >= threshold).astype(int)

    TN, FP, FN, TP =  metrics.confusion_matrix(y_test[0:][:,1], y_pred).ravel()

    Sens = TP/(TP+FN) if TP+FN > 0 else 0.0
    Spec = TN/(FP+TN) if FP+TN > 0 else 0.0
    Acc = (TP+TN)/(TP+FP+TN+FN)
    MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)) if TP+FP > 0 and FP+TN > 0 and TP+FN and TN+FN else 0.0
   
    return TP,FP,TN,FN,Sens,Spec,Acc,MCC,AUC,fpr,tpr,thresholds[ix],gmeans[ix]

# %%
if(VALIDATION_MODE=="cross"):
	
	kfold = KFold(n_splits = K_Fold, shuffle = True, random_state = 2)
	results=[]
	i=1
	for train_index, test_index in kfold.split(x_train):
		print(i,"/",K_Fold,'\n')
	
		X_train, X_test = x_train[train_index], x_train[test_index]
		Y_train, Y_test = y_train[train_index], y_train[test_index]
	
		model = MCNN.DeepScan(
            num_class=NUM_CLASSES,
            maxseq=MAXSEQ,
            input_shape=(1, MAXSEQ, NUM_FEATURE),
    		num_filters=NUM_FILTER,
			num_hidden=NUM_HIDDEN,
			window_sizes=WINDOW_SIZES)
		model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
		model.build(input_shape=X_train.shape)
		model.summary()
		history=model.fit(
			X_train,
			Y_train,
			batch_size=BATCH_SIZE,
			epochs=EPOCHS,
			verbose=0,
			shuffle=True
		)
		TP,FP,TN,FN,Sens,Spec,Acc,MCC,AUC,fpr,tpr,thresholds,gmeans = model_test(model, X_test, Y_test)
		results.append([Sens, Spec, Acc, MCC, AUC])
		i+=1
		
		del X_train
		del X_test
		del Y_train
		del Y_test
		gc.collect()
		
	mean_results = np.mean(results, axis=0)
	print(f'Sens={mean_results[0]:.4}, Spec={mean_results[1]:.4}, Acc={mean_results[2]:.4}, MCC={mean_results[3]:.4}, AUC={mean_results[4]:.4}\n')
# Out:
# 1 / 5
#
# Model: "deep_scan"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1, 10, 256)        524544
#
#  conv2d_1 (Conv2D)           (None, 1, 8, 256)         1048832
#
#  conv2d_2 (Conv2D)           (None, 1, 6, 256)         1573120
#
#  conv2d_3 (Conv2D)           (None, 1, 4, 256)         2097408
#
#  conv2d_4 (Conv2D)           (None, 1, 2, 256)         2621696
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 256)        0
#  )
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1000)              1281000
#
#  dense_1 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 9,148,602
# Trainable params: 9,148,602
# Non-trainable params: 0
# _________________________________________________________________
# 2023-10-05 11:07:03.252523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.286158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.286253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.287856: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.287934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.287983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.509257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.509383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.509436: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 11:07:03.509484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21836 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-10-05 11:07:12.629675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8903
# 2023-10-05 11:07:13.710847: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-05 11:07:13.712294: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f2e23c4f500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 11:07:13.712311: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090 Ti, Compute Capability 8.6
# 2023-10-05 11:07:13.715219: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 11:07:13.778525: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# (62828, 1, 11, 1024)
# 1964/1964 [==============================] - 2s 1ms/step
# 2 / 5
#
# Model: "deep_scan_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 1, 10, 256)        524544
#
#  conv2d_6 (Conv2D)           (None, 1, 8, 256)         1048832
#
#  conv2d_7 (Conv2D)           (None, 1, 6, 256)         1573120
#
#  conv2d_8 (Conv2D)           (None, 1, 4, 256)         2097408
#
#  conv2d_9 (Conv2D)           (None, 1, 2, 256)         2621696
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_6 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  max_pooling2d_9 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  flatten_8 (Flatten)         (None, 256)               0
#
#  flatten_9 (Flatten)         (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 1000)              1281000
#
#  dense_3 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 9,148,602
# Trainable params: 9,148,602
# Non-trainable params: 0
# _________________________________________________________________
# (62828, 1, 11, 1024)
# 1964/1964 [==============================] - 2s 1ms/step
# 3 / 5
#
# Model: "deep_scan_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 1, 10, 256)        524544
#
#  conv2d_11 (Conv2D)          (None, 1, 8, 256)         1048832
#
#  conv2d_12 (Conv2D)          (None, 1, 6, 256)         1573120
#
#  conv2d_13 (Conv2D)          (None, 1, 4, 256)         2097408
#
#  conv2d_14 (Conv2D)          (None, 1, 2, 256)         2621696
#
#  max_pooling2d_10 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_11 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_12 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_13 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 256)               0
#
#  flatten_11 (Flatten)        (None, 256)               0
#
#  flatten_12 (Flatten)        (None, 256)               0
#
#  flatten_13 (Flatten)        (None, 256)               0
#
#  flatten_14 (Flatten)        (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 1000)              1281000
#
#  dense_5 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 9,148,602
# Trainable params: 9,148,602
# Non-trainable params: 0
# _________________________________________________________________
# (62828, 1, 11, 1024)
# 1964/1964 [==============================] - 2s 1ms/step
# 4 / 5
#
# Model: "deep_scan_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 1, 10, 256)        524544
#
#  conv2d_16 (Conv2D)          (None, 1, 8, 256)         1048832
#
#  conv2d_17 (Conv2D)          (None, 1, 6, 256)         1573120
#
#  conv2d_18 (Conv2D)          (None, 1, 4, 256)         2097408
#
#  conv2d_19 (Conv2D)          (None, 1, 2, 256)         2621696
#
#  max_pooling2d_15 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_16 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_17 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_18 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_19 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 256)               0
#
#  flatten_16 (Flatten)        (None, 256)               0
#
#  flatten_17 (Flatten)        (None, 256)               0
#
#  flatten_18 (Flatten)        (None, 256)               0
#
#  flatten_19 (Flatten)        (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 1280)              0
#
#  dense_6 (Dense)             (None, 1000)              1281000
#
#  dense_7 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 9,148,602
# Trainable params: 9,148,602
# Non-trainable params: 0
# _________________________________________________________________
# (62828, 1, 11, 1024)
# 1964/1964 [==============================] - 2s 1ms/step
# 5 / 5
#
# Model: "deep_scan_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 1, 10, 256)        524544
#
#  conv2d_21 (Conv2D)          (None, 1, 8, 256)         1048832
#
#  conv2d_22 (Conv2D)          (None, 1, 6, 256)         1573120
#
#  conv2d_23 (Conv2D)          (None, 1, 4, 256)         2097408
#
#  conv2d_24 (Conv2D)          (None, 1, 2, 256)         2621696
#
#  max_pooling2d_20 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_21 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_22 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_23 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  max_pooling2d_24 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 256)               0
#
#  flatten_21 (Flatten)        (None, 256)               0
#
#  flatten_22 (Flatten)        (None, 256)               0
#
#  flatten_23 (Flatten)        (None, 256)               0
#
#  flatten_24 (Flatten)        (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_8 (Dense)             (None, 1000)              1281000
#
#  dense_9 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 9,148,602
# Trainable params: 9,148,602
# Non-trainable params: 0
# _________________________________________________________________
# (62827, 1, 11, 1024)
# 1964/1964 [==============================] - 2s 1ms/step
# Sens=0.9317, Spec=0.912, Acc=0.913, MCC=0.5461, AUC=0.9735

# %%
if(VALIDATION_MODE=="independent"):
	model = MCNN.DeepScan(
        num_class=NUM_CLASSES,
            maxseq=MAXSEQ,
            input_shape=(1, MAXSEQ, NUM_FEATURE),
    		num_filters=NUM_FILTER,
			num_hidden=NUM_HIDDEN,
			window_sizes=WINDOW_SIZES)
	model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
	model.build(input_shape=x_train.shape)
	model.fit(
		x_train,
		y_train,
		batch_size=BATCH_SIZE,
		epochs=EPOCHS,
        verbose=0,
		shuffle=True
    )
	TP,FP,TN,FN,Sens,Spec,Acc,MCC,AUC,fpr,tpr,thresholds,gmeans = model_test(model, x_test, y_test)
	display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=AUC, estimator_name='mCNN')
	display.plot()
	print(f'Best Threshold={thresholds}, G-Mean={gmeans}')
	print(f'TP={TP}, FP={FP}, TN={TN}, FN={FN}, Sens={Sens:.4f}, Spec={Spec:.4f}, Acc={Acc:.4f}, MCC={MCC:.4f}, AUC={AUC:.4f}\n')
# Out:
# 2023-10-05 11:18:38.102872: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 13.18GiB (rounded to 14153846784)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-10-05 11:18:38.102912: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-10-05 11:18:38.102917: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 45, Chunks in use: 45. 11.2KiB allocated for chunks. 11.2KiB in use in bin. 236B client-requested in use in bin.
# 2023-10-05 11:18:38.102920: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 2, Chunks in use: 0. 1.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102922: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 22, Chunks in use: 21. 23.0KiB allocated for chunks. 21.2KiB in use in bin. 21.0KiB client-requested in use in bin.
# 2023-10-05 11:18:38.102924: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102926: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 5, Chunks in use: 4. 22.5KiB allocated for chunks. 18.0KiB in use in bin. 15.6KiB client-requested in use in bin.
# 2023-10-05 11:18:38.102928: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 6, Chunks in use: 4. 52.5KiB allocated for chunks. 32.0KiB in use in bin. 31.2KiB client-requested in use in bin.
# 2023-10-05 11:18:38.102930: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 29.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102932: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102934: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102935: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102937: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102939: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102941: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.92MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102943: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 6, Chunks in use: 4. 15.10MiB allocated for chunks. 8.04MiB in use in bin. 8.00MiB client-requested in use in bin.
# 2023-10-05 11:18:38.102945: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 11, Chunks in use: 10. 59.71MiB allocated for chunks. 53.71MiB in use in bin. 49.77MiB client-requested in use in bin.
# 2023-10-05 11:18:38.102947: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 10, Chunks in use: 9. 88.04MiB allocated for chunks. 80.04MiB in use in bin. 71.77MiB client-requested in use in bin.
# 2023-10-05 11:18:38.102950: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 2, Chunks in use: 1. 38.90MiB allocated for chunks. 18.90MiB in use in bin. 10.00MiB client-requested in use in bin.
# 2023-10-05 11:18:38.102957: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102959: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102961: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 165.70MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102963: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 0. 20.96GiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-05 11:18:38.102967: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 13.18GiB was 256.00MiB, Chunk State:
# 2023-10-05 11:18:38.102972: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 10.41GiB | Requested Size: 8B | in_use: 0 | bin_num: 20, prev:   Size: 2.04MiB | Requested Size: 2.00MiB | in_use: 1 | bin_num: -1
# 2023-10-05 11:18:38.102975: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 10.55GiB | Requested Size: 2.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 6.00MiB | Requested Size: 6.00MiB | in_use: 1 | bin_num: -1, next:   Size: 4.88MiB | Requested Size: 4.88MiB | in_use: 1 | bin_num: -1
# 2023-10-05 11:18:38.102977: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 22897098752
# 2023-10-05 11:18:38.102980: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000000 of size 256 next 1
# 2023-10-05 11:18:38.102982: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000100 of size 1280 next 2
# 2023-10-05 11:18:38.102983: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000600 of size 256 next 3
# 2023-10-05 11:18:38.102985: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000700 of size 256 next 4
# 2023-10-05 11:18:38.102986: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000800 of size 256 next 6
# 2023-10-05 11:18:38.102988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000900 of size 1024 next 7
# 2023-10-05 11:18:38.102989: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000d00 of size 256 next 5
# 2023-10-05 11:18:38.102991: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000e00 of size 256 next 8
# 2023-10-05 11:18:38.102992: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee000f00 of size 1024 next 13
# 2023-10-05 11:18:38.102994: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001300 of size 256 next 11
# 2023-10-05 11:18:38.102995: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001400 of size 256 next 12
# 2023-10-05 11:18:38.102996: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001500 of size 1024 next 16
# 2023-10-05 11:18:38.102998: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001900 of size 256 next 17
# 2023-10-05 11:18:38.102999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001a00 of size 256 next 20
# 2023-10-05 11:18:38.103001: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001b00 of size 1024 next 21
# 2023-10-05 11:18:38.103002: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee001f00 of size 256 next 22
# 2023-10-05 11:18:38.103003: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee002000 of size 256 next 25
# 2023-10-05 11:18:38.103005: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee002100 of size 1024 next 28
# 2023-10-05 11:18:38.103006: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2fee002500 of size 256 next 26
# 2023-10-05 11:18:38.103008: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f2f
I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f32a760e700 of size 10529536 next 166
# 2023-10-05 11:18:38.103140: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f32a8019200 of size 768 next 75
# 2023-10-05 11:18:38.103141: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f32a8019500 of size 8192 next 174
# 2023-10-05 11:18:38.103143: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f32a801b500 of size 2010624 next 176
# 2023-10-05 11:18:38.103144: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f32a8206300 of size 2097152 next 73
# 2023-10-05 11:18:38.103146: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f32a8406300 of size 2138880 next 125
# 2023-10-05 11:18:38.103147: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f32a8610600 of size 11180243456 next 18446744073709551615
# 2023-10-05 11:18:38.103150: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-10-05 11:18:38.103152: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 45 Chunks of size 256 totalling 11.2KiB
# 2023-10-05 11:18:38.103154: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 20 Chunks of size 1024 totalling 20.0KiB
# 2023-10-05 11:18:38.103156: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-10-05 11:18:38.103158: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4096 totalling 12.0KiB
# 2023-10-05 11:18:38.103159: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6144 totalling 6.0KiB
# 2023-10-05 11:18:38.103161: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 8192 totalling 32.0KiB
# 2023-10-05 11:18:38.103163: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2097152 totalling 6.00MiB
# 2023-10-05 11:18:38.103164: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2138880 totalling 2.04MiB
# 2023-10-05 11:18:38.103166: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 4194304 totalling 12.00MiB
# 2023-10-05 11:18:38.103167: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 5120000 totalling 9.77MiB
# 2023-10-05 11:18:38.103169: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 6291456 totalling 24.00MiB
# 2023-10-05 11:18:38.103171: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 8329216 totalling 7.94MiB
# 2023-10-05 11:18:38.103172: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 8388608 totalling 40.00MiB
# 2023-10-05 11:18:38.103174: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 10485760 totalling 30.00MiB
# 2023-10-05 11:18:38.103175: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 10529536 totalling 10.04MiB
# 2023-10-05 11:18:38.103177: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19816448 totalling 18.90MiB
# 2023-10-05 11:18:38.103179: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 160.77MiB
# 2023-10-05 11:18:38.103180: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 22897098752 memory_limit_: 22897098752 available bytes: 0 curr_region_allocation_bytes_: 45794197504
# 2023-10-05 11:18:38.103185: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     22897098752
# InUse:                       168579072
# MaxInUse:                  14661928960
# NumAllocs:                     4095880
# MaxAllocSize:              11454735616
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-10-05 11:18:38.103189: W tensorflow/tsl/framework/bfc_allocator.cc:497] *________________________________________________***________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[7], line 11
#       9 	model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      10 	model.build(input_shape=x_train.shape)
# ---> 11 	model.fit(
#      12 		x_train,
#      13 		y_train,
#      14 		batch_size=BATCH_SIZE,
#      15 		epochs=EPOCHS,
#      16         verbose=0,
#      17 		shuffle=True
#      18     )
#      19 	TP,FP,TN,FN,Sens,Spec,Acc,MCC,AUC,fpr,tpr,thresholds,gmeans = model_test(model, x_test, y_test)
#      20 	display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=AUC, estimator_name='mCNN')
#
# File ~/anaconda3/envs/TF/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/envs/TF/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
